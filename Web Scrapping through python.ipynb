# %%
# library include
from bs4 import BeautifulSoup
import requests
# for storing and showing the output we have to import pandas
import pandas as pd
#variable
wiki_url = 'https://en.wikipedia.org/wiki/List_of_current_members_of_the_United_States_House_of_Representatives'
tableid = 'votingmembers'

response = requests.get(wiki_url)
soup=BeautifulSoup(response.text, 'html.parser')

print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of current members of the United States House of Representatives - Wikipedia</title>
# ...

# %%
#variable congress_table
congress_table = soup.find('table',attrs={'id':tableid})
print(congress_table)
# Out:
# <table class="wikitable sortable" id="votingmembers">
# <tbody><tr style="vertical-align:bottom">
# <th>District
# </th>
# <th>Member
# </th>
# <th colspan="2">Party
# </th>
# <th>Prior experience
# </th>
# <th>Education
# </th>
# <th>Assumed office
# </th>
# <th>Residence
# </th>
# <th>Born<sup class="reference" id="cite_ref-born_4-0"><a href="#cite_note-born-4">[4]</a></sup>
# </th></tr>
# <tr>
# <td><span data-sort-value="Alabama01 !"><a href="/wiki/Alabama%27s_1st_congressional_district" title="Alabama's 1st congressional district">Alabama 1</a></span>
# </td>
# ...

# %%
#variable data frame 
df=pd.read_html(str(congress_table))
print(df)
# Out:
# [             District                  Member Party     Party.1  \
# 0           Alabama 1              Jerry Carl   NaN  Republican
# 1           Alabama 2             Barry Moore   NaN  Republican
# 2           Alabama 3             Mike Rogers   NaN  Republican
# 3           Alabama 4         Robert Aderholt   NaN  Republican
# 4           Alabama 5               Mo Brooks   NaN  Republican
# 5           Alabama 6             Gary Palmer   NaN  Republican
# 6           Alabama 7            Terri Sewell   NaN  Democratic
# 7     Alaska at-large               Don Young   NaN  Republican
# 8           Arizona 1          Tom O'Halleran   NaN  Democratic
# 9           Arizona 2         Ann Kirkpatrick   NaN  Democratic
# 10          Arizona 3           Raúl Grijalva   NaN  Democratic
# 11          Arizona 4              Paul Gosar   NaN  Republican
# 12          Arizona 5              Andy Biggs   NaN  Republican
# 13          Arizona 6        David Schweikert   NaN  Republican
# ...
